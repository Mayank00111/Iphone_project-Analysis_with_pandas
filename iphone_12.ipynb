# %%
import pandas as pd

# %%
df = pd.read_csv('iphone.csv')

# %%
df.head(2)
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
#
#      Mrp  Number Of Ratings  Number Of Reviews               Upc  Star Rating  \
# 0  49900               3431                356  MOBEXRGV7EHHTGUH          4.6
# 1  84900               3431                356  MOBEXRGVAC6TJT4F          4.6
#
#     Ram
# 0  2 GB
# 1  2 GB

# %%
#12- which iphone has 3rd highest MRP

df.sort_values(by = 'Mrp', ascending = False, inplace = True)

# %%
df.head(4)
# Out:
#                                     Product Name  \
# 41    APPLE iPhone 12 Pro (Pacific Blue, 512 GB)
# 24          APPLE iPhone 12 Pro (Silver, 512 GB)
# 19      APPLE iPhone 11 Pro (Space Grey, 512 GB)
# 21  APPLE iPhone 11 Pro (Midnight Green, 512 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 41  https://www.flipkart.com/apple-iphone-12-pro-p...  Apple      140900
# 24  https://www.flipkart.com/apple-iphone-12-pro-s...  Apple      140900
# 19  https://www.flipkart.com/apple-iphone-11-pro-s...  Apple      117900
# 21  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117900
#
#        Mrp  Number Of Ratings  Number Of Reviews               Upc  \
# 41  149900                545                 42  MOBFWBYZTHSXKMGW
# 24  149900                542                 42  MOBFWBYZ5UY6ZBVA
# 19  140300               7088                523  MOBFKCTSRTHRQTFT
# 21  140300               7088                523  MOBFKCTSSJCWYGCC
#
# ...

# %%
df.loc[3]
# Out:
# Product Name                           APPLE iPhone 8 (Silver, 256 GB)
# Product URL          https://www.flipkart.com/apple-iphone-8-silver...
# Brand                                                            Apple
# Sale Price                                                       77000
# Mrp                                                              77000
# Number Of Ratings                                                11202
# Number Of Reviews                                                  794
# Upc                                                   MOBEXRGVMZWUHCBA
# Star Rating                                                        NaN
# Ram                                                               2 GB
# Name: 3, dtype: object

# %%
#12- which iphone has 3rd highest MRP

sorted_df = df.sort_values(by = 'Mrp', ascending = False).reset_index(drop= True)

# %%
sorted_df                                      #index is resetted this time which don't happen when we have done inplace = True
                                               #inplace = True just sorted the order but don't change the index
# Out:
#                                       Product Name  \
# 0       APPLE iPhone 12 Pro (Pacific Blue, 512 GB)
# 1             APPLE iPhone 12 Pro (Silver, 512 GB)
# 2         APPLE iPhone 11 Pro (Space Grey, 512 GB)
# 3     APPLE iPhone 11 Pro (Midnight Green, 512 GB)
# 4   APPLE iPhone 12 Pro Max (Pacific Blue, 256 GB)
# ..                                             ...
# 57                 APPLE iPhone SE (Black, 128 GB)
# 58                 APPLE iPhone SE (White, 128 GB)
# 59                   APPLE iPhone SE (Red, 128 GB)
# 60                  APPLE iPhone SE (Black, 64 GB)
# 61                  APPLE iPhone SE (White, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 0   https://www.flipkart.com/apple-iphone-12-pro-p...  Apple      140900
# 1   https://www.flipkart.com/apple-iphone-12-pro-s...  Apple      140900
# 2   https://www.flipkart.com/apple-iphone-11-pro-s...  Apple      117900
# ...

# %%
# Get the iPhone with the 3rd highest MRP
third_highest_mrp_iphone = sorted_df.loc[2]

# %%
third_highest_mrp_iphone
# Out:
# Product Name                  APPLE iPhone 11 Pro (Space Grey, 512 GB)
# Product URL          https://www.flipkart.com/apple-iphone-11-pro-s...
# Brand                                                            Apple
# Sale Price                                                      117900
# Mrp                                                             140300
# Number Of Ratings                                                 7088
# Number Of Reviews                                                  523
# Upc                                                   MOBFKCTSRTHRQTFT
# Star Rating                                                        4.6
# Ram                                                               4 GB
# Name: 2, dtype: object
