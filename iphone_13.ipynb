# %%
import pandas as pd

# %%
df = pd.read_csv('iphone.csv')

# %%
df.shape
# Out:
# (62, 10)

# %%
#13- what is the average mrp of iphones which costs above 100,000

sorted_df = df.sort_values(by = 'Mrp', ascending = True).reset_index()

# %%
sorted_df
# Out:
#     index                                    Product Name  \
# 0      52                  APPLE iPhone SE (White, 64 GB)
# 1      57                  APPLE iPhone SE (Black, 64 GB)
# 2      53                 APPLE iPhone SE (Black, 128 GB)
# 3      55                   APPLE iPhone SE (Red, 128 GB)
# 4      54                 APPLE iPhone SE (White, 128 GB)
# ..    ...                                             ...
# 57     25  APPLE iPhone 12 Pro Max (Pacific Blue, 256 GB)
# 58     21    APPLE iPhone 11 Pro (Midnight Green, 512 GB)
# 59     19        APPLE iPhone 11 Pro (Space Grey, 512 GB)
# 60     24            APPLE iPhone 12 Pro (Silver, 512 GB)
# 61     41      APPLE iPhone 12 Pro (Pacific Blue, 512 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 0   https://www.flipkart.com/apple-iphone-se-white...  Apple       29999
# 1   https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
# 2   https://www.flipkart.com/apple-iphone-se-black...  Apple       34999
# 3   https://www.flipkart.com/apple-iphone-se-red-1...  Apple       34999
# 4   https://www.flipkart.com/apple-iphone-se-white...  Apple       34999
# ..                                                ...    ...         ...
# 57  https://www.flipkart.com/apple-iphone-12-pro-m...  Apple      130900
# 58  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117900
# 59  https://www.flipkart.com/apple-iphone-11-pro-s...  Apple      117900
# 60  https://www.flipkart.com/apple-iphone-12-pro-s...  Apple      140900
# 61  https://www.flipkart.com/apple-iphone-12-pro-p...  Apple      140900
#
#        Mrp  Number Of Ratings  Number Of Reviews               Upc  \
# 0    39900              95807               8154  MOBFWQ6BGWDVGF3E
# 1    39900              95909               8161  MOBFWQ6BR3MK7AUG
# 2    44900              95909               8161  MOBFWQ6BHUEVZPXD
# 3    44900              95909               8161  MOBFWQ6BJTVFKPEJ
# 4    44900              95807               8154  MOBFWQ6BJEHMUUZY
# ..     ...                ...                ...               ...
# 57  139900                580                 45  MOBFWBYZ8STJXCVT
# 58  140300               7088                523  MOBFKCTSSJCWYGCC
# 59  140300               7088                523  MOBFKCTSRTHRQTFT
# 60  149900                542                 42  MOBFWBYZ5UY6ZBVA
# 61  149900                545                 42  MOBFWBYZTHSXKMGW
#
#     Star Rating   Ram
# 0           4.5  2 GB
# 1           4.5  4 GB
# 2           4.5  2 GB
# 3           4.5  2 GB
# 4           4.5  2 GB
# ..          ...   ...
# 57          4.6  6 GB
# 58          4.6  4 GB
# 59          4.6  4 GB
# 60          4.5  4 GB
# 61          4.5  4 GB
#
# [62 rows x 11 columns]

# %%
#13- what is the average mrp of iphones which costs above 100,000

filt = df[df['Mrp'] >= 100000]

# %%
filt.head(4)
# Out:
#                                         Product Name  \
# 14            APPLE iPhone 11 Pro Max (Gold, 256 GB)
# 15             APPLE iPhone 11 Pro Max (Gold, 64 GB)
# 16  APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 17       APPLE iPhone 11 Pro Max (Space Grey, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 14  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      131900
# 15  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117100
# 16  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      131900
# 17  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117100
#
#        Mrp  Number Of Ratings  Number Of Reviews               Upc  \
# 14  131900               1078                101  MOBFKCTS7HCHSPFH
# 15  117100               1078                101  MOBFKCTSAPAYNSGG
# 16  131900               1078                101  MOBFKCTSCAAKGQV7
# 17  117100               1078                101  MOBFKCTSKDMKCGQS
#
#     Star Rating   Ram
# 14          4.7  4 GB
# 15          4.7  4 GB
# 16          4.7  4 GB
# 17          4.7  4 GB

# %%
average_mrp = filt['Mrp'].mean()

# %%
average_mrp
# Out:
# 130559.09090909091
